# %% [markdown]
# <font size = "40"> This is my first Jupyter notebook.

# %%
print("My name is Joaquin Pauig")
# Out:
# My name is Joaquin Pauig

# %% [markdown]
# <style font = 10> This is my first Jupyter notebook.
