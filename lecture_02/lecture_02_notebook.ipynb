# %% [markdown]
# commit to main --> push to origin

# %% [markdown]
# make a copy of your notes! that way your changes do NOT conflict with his changes

# %% [markdown]
# update from upstream/main in the branch section of github = get new files

# %%
print("Goodbye!")
# Out:
# Goodbye!
