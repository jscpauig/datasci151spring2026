# %% [markdown]
# This is a markdown!
#
#
# These are where lecture notes are (in edit mode), checkmark = render

# %% [markdown]
# <font size = "4"> Font size 4
#
# <font size = "10"> Font size 10
#
# <font size = "1"> Font size 1
#
#
# or use a bunch of pounds...
# # 1pound
# ## 2pounds
# #### 4pounds

# %% [markdown]
# This is a code block below! press shift-enter to run the cell

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# There is a white dot right next to your file name. If that dot is there, that means your file is NOT SAVED! CMD + S
